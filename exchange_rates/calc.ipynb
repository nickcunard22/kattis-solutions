# %%
def commision(v):
    return v - v * .03

# %%
balance = 1000
u = balance / .93
u = u - u * .03

print(u)
# Out:
# 1043.010752688172

# %%
c = u * .99
c = c - c * .03
c = round(c, 2)
print(c)
# Out:
# 1001.6
